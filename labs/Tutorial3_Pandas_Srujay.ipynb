# %% [markdown]
# <a href="https://colab.research.google.com/github/srujayreddyv/CSUS-CSC177-DataAnalyticsAndMining/blob/main/labs/Tutorial3_Pandas_Srujay.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Module 3: Introduction to Pandas
#
# Pandas is an open source library providing high-performance, easy-to-use data structures and data analysis tools for the Python programming language.  Pandas is built on top of Numpy.
#
# - [pandas main page](http://pandas.pydata.org/)
# - How to install pandas?   [Anaconda distribution of Python](https://www.continuum.io/downloads) (includes pandas)
#
# *** Online official documentation should be your best friend! ***
#
# ### Pandas gives you two data structures:
#
# #### Series:  One-dimensional numpy array with a labeled index.
# #### Dataframe:  A collection of multiple Series with the same labeled index. (Two-dimensional)

# %% [markdown]
# ## Series
#
# A Series object consists of a one-dimensional array of values, whose elements can be referenced using an index array. A Series object can be created from a list, a numpy array, or a Python dictionary. You can apply most of the numpy functions on the Series object.

# %%
from pandas import Series

s = Series([3.1, 2.4, -1.7, 0.2, -2.9, 4.5])   # creating a series from a list
print(s)
print('Values=', s.values)     # display values of the Series
print('Index=', s.index)       # display indices of the Series
# Out:
# 0    3.1
# 1    2.4
# 2   -1.7
# 3    0.2
# 4   -2.9
# 5    4.5
# dtype: float64
# Values= [ 3.1  2.4 -1.7  0.2 -2.9  4.5]
# Index= RangeIndex(start=0, stop=6, step=1)

# %%
import numpy as np

s2 = Series(np.random.randn(6))  # creating a series from a numpy ndarray
print(s2)
print('Values=', s2.values)   # display values of the Series
print('Index=', s2.index)     # display indices of the Series
# Out:
# 0    1.969177
# 1   -0.507025
# 2    0.195755
# 3   -0.551001
# 4    1.428640
# 5    0.810146
# dtype: float64
# Values= [ 1.96917715 -0.50702499  0.19575534 -0.55100056  1.42863973  0.81014582]
# Index= RangeIndex(start=0, stop=6, step=1)

# %%
s3 = Series([1.2,2.5,-2.2,3.1,-0.8,-3.2],
            index = ['Jan 1','Jan 2','Jan 3','Jan 4','Jan 5','Jan 6',])
print(s3)
print('Values=', s3.values)   # display values of the Series
print('Index=', s3.index)     # display indices of the Series
# Out:
# Jan 1    1.2
# Jan 2    2.5
# Jan 3   -2.2
# Jan 4    3.1
# Jan 5   -0.8
# Jan 6   -3.2
# dtype: float64
# Values= [ 1.2  2.5 -2.2  3.1 -0.8 -3.2]
# Index= Index(['Jan 1', 'Jan 2', 'Jan 3', 'Jan 4', 'Jan 5', 'Jan 6'], dtype='object')

# %%
capitals = {'MI': 'Lansing', 'CA': 'Sacramento', 'TX': 'Austin', 'MN': 'St Paul'}

s4 = Series(capitals)   # creating a series from dictionary object
print(s4)
print('Values=', s4.values)   # display values of the Series
print('Index=', s4.index)     # display indices of the Series
# Out:
# MI       Lansing
# CA    Sacramento
# TX        Austin
# MN       St Paul
# dtype: object
# Values= ['Lansing' 'Sacramento' 'Austin' 'St Paul']
# Index= Index(['MI', 'CA', 'TX', 'MN'], dtype='object')

# %%
s3 = Series([1.2,2.5,-2.2,3.1,-0.8,-3.2],
            index = ['Jan 1','Jan 2','Jan 3','Jan 4','Jan 5','Jan 6',])
print(s3)

# Accessing elements of a Series

print('\ns3[2]=', s3[2])        # display third element of the Series
print('s3[\'Jan 3\']=', s3['Jan 3'])   # indexing element of a Series

print('\ns3[1:3]=')             # display a slice of the Series
print(s3[1:3])
print('s3.iloc([1:3])=')      # display a slice of the Series
print(s3.iloc[1:3])
# Out:
# Jan 1    1.2
# Jan 2    2.5
# Jan 3   -2.2
# Jan 4    3.1
# Jan 5   -0.8
# Jan 6   -3.2
# dtype: float64
#
# s3[2]= -2.2
# s3['Jan 3']= -2.2
#
# s3[1:3]=
# Jan 2    2.5
# Jan 3   -2.2
# dtype: float64
# s3.iloc([1:3])=
# Jan 2    2.5
# Jan 3   -2.2
# dtype: float64

# %%
print('shape =', s3.shape)  # get the dimension of the Series
print('size =', s3.size)    # get the # of elements of the Series
# Out:
# shape = (6,)
# size = 6

# %%
print(s3[s3 > 0])   # applying filter to select elements of the Series
# Out:
# Jan 1    1.2
# Jan 2    2.5
# Jan 4    3.1
# dtype: float64

# %%
print(s3 + 4)       # applying scalar operation on a numeric Series
print(s3 / 4)
# Out:
# Jan 1    5.2
# Jan 2    6.5
# Jan 3    1.8
# Jan 4    7.1
# Jan 5    3.2
# Jan 6    0.8
# dtype: float64
# Jan 1    0.300
# Jan 2    0.625
# Jan 3   -0.550
# Jan 4    0.775
# Jan 5   -0.200
# Jan 6   -0.800
# dtype: float64

# %%
print(np.log(s3 + 4))    # applying numpy math functions to a numeric Series
# Out:
# Jan 1    1.648659
# Jan 2    1.871802
# Jan 3    0.587787
# Jan 4    1.960095
# Jan 5    1.163151
# Jan 6   -0.223144
# dtype: float64

# %% [markdown]
# ## DataFrame
#
# A DataFrame object is a tabular, spreadsheet-like data structure containing a collection of columns, each of which can be of different types (numeric, string, boolean, etc). Unlike Series, a DataFrame has distinct row and column indices. There are many ways to create a DataFrame object (e.g., from a dictionary, list of tuples, or even numpy's ndarrays).

# %%
from pandas import DataFrame

cars = {'make': ['Ford', 'Honda', 'Toyota', 'Tesla'],
       'model': ['Taurus', 'Accord', 'Camry', 'Model S'],
       'MSRP': [27595, 23570, 23495, 68000]}
carData = DataFrame(cars)   # creating DataFrame from dictionary
carData                     # display the table
# Out:
#      make    model   MSRP
# 0    Ford   Taurus  27595
# 1   Honda   Accord  23570
# 2  Toyota    Camry  23495
# 3   Tesla  Model S  68000

# %%
print(carData.index)       # print the row indices
print(carData.columns)     # print the column indices
# Out:
# RangeIndex(start=0, stop=4, step=1)
# Index(['make', 'model', 'MSRP'], dtype='object')

# %%
carData2 = DataFrame(cars, index = [1,2,3,4])  # change the row index
carData2['year'] = 2018    # add column with same value
carData2['dealership'] = ['Courtesy Ford','Capital Honda','Spartan Toyota','N/A']
carData2                   # display table
# Out:
#      make    model   MSRP  year      dealership
# 1    Ford   Taurus  27595  2018   Courtesy Ford
# 2   Honda   Accord  23570  2018   Capital Honda
# 3  Toyota    Camry  23495  2018  Spartan Toyota
# 4   Tesla  Model S  68000  2018             N/A

# %% [markdown]
# Creating DataFrame from a list of tuples.

# %%
tuplelist = [(2011,45.1,32.4),(2012,42.4,34.5),(2013,47.2,39.2),
              (2014,44.2,31.4),(2015,39.9,29.8),(2016,41.5,36.7)]
columnNames = ['year','temp','precip']
weatherData = DataFrame(tuplelist, columns=columnNames)
weatherData
# Out:
#    year  temp  precip
# 0  2011  45.1    32.4
# 1  2012  42.4    34.5
# 2  2013  47.2    39.2
# 3  2014  44.2    31.4
# 4  2015  39.9    29.8
# 5  2016  41.5    36.7

# %% [markdown]
# Creating DataFrame from numpy ndarray

# %%
import numpy as np

npdata = np.random.randn(5,3)  # create a 5 by 3 random matrix
columnNames = ['x1','x2','x3']
data = DataFrame(npdata, columns=columnNames)
data
# Out:
#          x1        x2        x3
# 0  0.850415 -0.737636 -1.537933
# 1 -0.208407  0.271587 -0.996442
# 2  1.097428  0.962038 -0.516951
# 3 -0.829365 -1.018118 -0.705371
# 4 -2.045070 -0.155677  1.350454

# %% [markdown]
# The elements of a DataFrame can be accessed in many ways.

# %%
# accessing an entire column will return a Series object

print(data['x2'])
print(type(data['x2']))
# Out:
# 0   -0.737636
# 1    0.271587
# 2    0.962038
# 3   -1.018118
# 4   -0.155677
# Name: x2, dtype: float64
# <class 'pandas.core.series.Series'>

# %%
# accessing an entire row will return a Series object

print('Row 3 of data table:')
print(data.iloc[2])       # returns the 3rd row of DataFrame
print(type(data.iloc[2]))
print('\nRow 3 of car data table:')
print(carData2.iloc[2])   # row contains objects of different types
# Out:
# Row 3 of data table:
# x1    1.097428
# x2    0.962038
# x3   -0.516951
# Name: 2, dtype: float64
# <class 'pandas.core.series.Series'>
#
# Row 3 of car data table:
# make                  Toyota
# model                  Camry
# MSRP                   23495
# year                    2018
# dealership    Spartan Toyota
# Name: 3, dtype: object

# %%
# accessing a specific element of the DataFrame

print(carData2.iloc[1,2])      # retrieving second row, third column
print(carData2.loc[1,'model']) # retrieving second row, column named 'model'

# accessing a slice of the DataFrame

print('carData2.iloc[1:3,1:3]=')
print(carData2.iloc[1:3,1:3])
# Out:
# 23570
# Taurus
# carData2.iloc[1:3,1:3]=
#     model   MSRP
# 2  Accord  23570
# 3   Camry  23495

# %%
print('carData2.shape =', carData2.shape)
print('carData2.size =', carData2.size)
# Out:
# carData2.shape = (4, 5)
# carData2.size = 20

# %%
# selection and filtering

print('carData2[carData2.MSRP > 25000]')
print(carData2[carData2.MSRP > 25000])
# Out:
# carData2[carData2.MSRP > 25000]
#     make    model   MSRP  year     dealership
# 1   Ford   Taurus  27595  2018  Courtesy Ford
# 4  Tesla  Model S  68000  2018            N/A

# %%
# conventional way to import pandas
import pandas as pd

# %% [markdown]
# ### Read a tabular data file

# %%
# read a dataset of Chipotle orders directly from a URL and store the results in a DataFrame
#orders = pd.read_table('data/chipotle.tsv')

from google.colab import files
uploaded = files.upload()

orders = pd.read_table('chipotle.tsv')
# Out:
#      <input type="file" id="files-1149f86b-3d6c-4c65-a134-b1563e86ebfd" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1149f86b-3d6c-4c65-a134-b1563e86ebfd">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# examine the first 5 rows
orders.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %% [markdown]
# Documentation for [**`read_table`**](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.read_table.html)

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-ee1be22f-32d9-455b-8917-c07ca8f0ba27" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ee1be22f-32d9-455b-8917-c07ca8f0ba27">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# read a dataset of movie reviewers (modifying the default parameter values for read_table)
user_cols = ['user_id', 'age', 'gender', 'occupation', 'zip_code']
users = pd.read_table('u.user', sep='|', header=None, names=user_cols)

# %%
# examine the first 5 rows
users.head()
# Out:
#    user_id  age gender  occupation zip_code
# 0        1   24      M  technician    85711
# 1        2   53      F       other    94043
# 2        3   23      M      writer    32067
# 3        4   24      M  technician    43537
# 4        5   33      F       other    15213

# %%
users
# Out:
#      user_id  age gender     occupation zip_code
# 0          1   24      M     technician    85711
# 1          2   53      F          other    94043
# 2          3   23      M         writer    32067
# 3          4   24      M     technician    43537
# 4          5   33      F          other    15213
# ..       ...  ...    ...            ...      ...
# 938      939   26      F        student    33319
# 939      940   32      M  administrator    02215
# 940      941   20      M        student    97229
# 941      942   48      F      librarian    78209
# 942      943   22      M        student    77841
#
# [943 rows x 5 columns]

# %% [markdown]
# ### Selecting a pandas Series from a DataFrame

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-92e623ea-1a67-4756-aeb6-4d36a3cc50df" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-92e623ea-1a67-4756-aeb6-4d36a3cc50df">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# read a dataset of UFO reports into a DataFrame
ufo = pd.read_table('ufo.csv', sep=',')

# %%
# read_csv is equivalent to read_table, except it assumes a comma separator
ufo = pd.read_csv('ufo.csv')

# %%
# examine the first 5 rows
ufo.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
# select the 'City' Series using bracket notation
ufo['City']

# or equivalently, use dot notation
ufo.City
# Out:
# 0                      Ithaca
# 1                 Willingboro
# 2                     Holyoke
# 3                     Abilene
# 4        New York Worlds Fair
#                  ...
# 18236              Grant Park
# 18237             Spirit Lake
# 18238             Eagle River
# 18239             Eagle River
# 18240                    Ybor
# Name: City, Length: 18241, dtype: object

# %%
# create a new 'Location' Series (must use bracket notation to define the Series name)
ufo['Location'] = ufo.City + ', ' + ufo.State
ufo.head()
# Out:
#                    City Colors Reported Shape Reported State             Time  \
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00
#
#                    Location
# 0                Ithaca, NY
# 1           Willingboro, NJ
# 2               Holyoke, CO
# 3               Abilene, KS
# 4  New York Worlds Fair, NY

# %% [markdown]
# ### Basic Stats

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-e9d7293b-c1bf-41a3-8d3f-c22030482544" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e9d7293b-c1bf-41a3-8d3f-c22030482544">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# read a dataset of top-rated IMDb movies into a DataFrame
movies = pd.read_csv('imdb_1000.csv')

# %%
# example method: show the first 5 rows
movies.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
# display the full (non-truncated) dataframe information

pd.set_option('display.max_colwidth', -1)
# Out:
# <ipython-input-42-fe1b580af046>:3: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   pd.set_option('display.max_colwidth', -1)

# %%
# example method: show the first 5 rows
movies.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0  9.3          The Shawshank Redemption  R              Crime   142
# 1  9.2          The Godfather             R              Crime   175
# 2  9.1          The Godfather: Part II    R              Crime   200
# 3  9.0          The Dark Knight           PG-13          Action  152
# 4  8.9          Pulp Fiction              R              Crime   154
#
#                                                 actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunton']
# 1  [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duvall']
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron Eckhart']
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L. Jackson']

# %%
# example method: calculate summary statistics
movies.describe()
# Out:
#        star_rating    duration
# count  979.000000   979.000000
# mean   7.889785     120.979571
# std    0.336069     26.218010
# min    7.400000     64.000000
# 25%    7.600000     102.000000
# 50%    7.800000     117.000000
# 75%    8.100000     134.000000
# max    9.300000     242.000000

# %%
# example attribute: number of rows and columns
movies.shape
# Out:
# (979, 6)

# %%
# example attribute: data type of each column
movies.dtypes
# Out:
# star_rating       float64
# title             object
# content_rating    object
# genre             object
# duration          int64
# actors_list       object
# dtype: object

# %% [markdown]
# ### Remove columns from DataFrame

# %%
# read a dataset of UFO reports into a DataFrame
ufo = pd.read_csv('ufo.csv')
ufo.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0  Ithaca                NaN             TRIANGLE       NY    6/1/1930 22:00
# 1  Willingboro           NaN             OTHER          NJ    6/30/1930 20:00
# 2  Holyoke               NaN             OVAL           CO    2/15/1931 14:00
# 3  Abilene               NaN             DISK           KS    6/1/1931 13:00
# 4  New York Worlds Fair  NaN             LIGHT          NY    4/18/1933 19:00

# %%
# remove a single column (axis=1 refers to columns)
ufo.drop('Colors Reported', axis=1, inplace=True)     # inplace is True means that I want to change the underlying data.
ufo.head()
# Out:
#                    City Shape Reported State             Time
# 0  Ithaca                TRIANGLE       NY    6/1/1930 22:00
# 1  Willingboro           OTHER          NJ    6/30/1930 20:00
# 2  Holyoke               OVAL           CO    2/15/1931 14:00
# 3  Abilene               DISK           KS    6/1/1931 13:00
# 4  New York Worlds Fair  LIGHT          NY    4/18/1933 19:00

# %% [markdown]
# Documentation for [**`drop`**](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.drop.html)

# %%
# remove multiple columns at once
ufo.drop(['City', 'State'], axis=1, inplace=True)

# %%
# dataframe supports slicing
ufo[0:5]
# Out:
#   Shape Reported             Time
# 0  TRIANGLE       6/1/1930 22:00
# 1  OTHER          6/30/1930 20:00
# 2  OVAL           2/15/1931 14:00
# 3  DISK           6/1/1931 13:00
# 4  LIGHT          4/18/1933 19:00

# %%
# remove multiple rows at once (axis=0 refers to rows)
ufo.drop([0, 1], axis=0, inplace=True)    # rows with indices of 0 and 1 removed
ufo.head()
# Out:
#   Shape Reported             Time
# 2  OVAL           2/15/1931 14:00
# 3  DISK           6/1/1931 13:00
# 4  LIGHT          4/18/1933 19:00
# 5  DISK           9/15/1934 15:30
# 6  CIRCLE         6/15/1935 0:00

# %% [markdown]
# ### Sort a pandas Series or a DataFrame

# %%
# read a dataset of top-rated IMDb movies into a DataFrame
movies = pd.read_csv('imdb_1000.csv')
movies.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0  9.3          The Shawshank Redemption  R              Crime   142
# 1  9.2          The Godfather             R              Crime   175
# 2  9.1          The Godfather: Part II    R              Crime   200
# 3  9.0          The Dark Knight           PG-13          Action  152
# 4  8.9          Pulp Fiction              R              Crime   154
#
#                                                 actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunton']
# 1  [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duvall']
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron Eckhart']
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L. Jackson']

# %% [markdown]
# **Note:** None of the sorting methods below affect the underlying data. (In other words, the sorting is temporary).

# %% [markdown]
# How to sort a series?

# %%
# sort the 'title' Series in ascending order (returns a Series)
movies.title.sort_values()
# Out:
# 542    (500) Days of Summer
# 5      12 Angry Men
# 201    12 Years a Slave
# 698    127 Hours
# 110    2001: A Space Odyssey
#                ...
# 955    Zero Dark Thirty
# 677    Zodiac
# 615    Zombieland
# 526    Zulu
# 864    [Rec]
# Name: title, Length: 979, dtype: object

# %%
# sort in descending order instead
movies.title.sort_values(ascending=False).head()
# Out:
# 864    [Rec]
# 526    Zulu
# 615    Zombieland
# 677    Zodiac
# 955    Zero Dark Thirty
# Name: title, dtype: object

# %% [markdown]
# How to sort the entire dataframe?

# %%
# sort the entire DataFrame by the 'title' Series (returns a DataFrame)
movies.sort_values('title').head()
# Out:
#      star_rating                  title content_rating      genre  duration  \
# 542  7.8          (500) Days of Summer   PG-13          Comedy     95
# 5    8.9          12 Angry Men           NOT RATED      Drama      96
# 201  8.1          12 Years a Slave       R              Biography  134
# 698  7.6          127 Hours              R              Adventure  94
# 110  8.3          2001: A Space Odyssey  G              Mystery    160
#
#                                                                    actors_list
# 542  [u'Zooey Deschanel', u'Joseph Gordon-Levitt', u'Geoffrey Arend']
# 5    [u'Henry Fonda', u'Lee J. Cobb', u'Martin Balsam']
# 201  [u'Chiwetel Ejiofor', u'Michael Kenneth Williams', u'Michael Fassbender']
# 698  [u'James Franco', u'Amber Tamblyn', u'Kate Mara']
# 110  [u'Keir Dullea', u'Gary Lockwood', u'William Sylvester']

# %%
# sort in descending order instead
movies.sort_values('title', ascending=False).head()
# Out:
#      star_rating             title content_rating   genre  duration  \
# 864  7.5          [Rec]             R              Horror  78
# 526  7.8          Zulu              UNRATED        Drama   138
# 615  7.7          Zombieland        R              Comedy  88
# 677  7.7          Zodiac            R              Crime   157
# 955  7.4          Zero Dark Thirty  R              Drama   157
#
#                                                          actors_list
# 864  [u'Manuela Velasco', u'Ferran Terraza', u'Jorge-Yamam Serrano']
# 526  [u'Stanley Baker', u'Jack Hawkins', u'Ulla Jacobsson']
# 615  [u'Jesse Eisenberg', u'Emma Stone', u'Woody Harrelson']
# 677  [u'Jake Gyllenhaal', u'Robert Downey Jr.', u'Mark Ruffalo']
# 955  [u'Jessica Chastain', u'Joel Edgerton', u'Chris Pratt']

# %% [markdown]
# Documentation for [**`sort_values`**](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.sort_values.html) for a **DataFrame**.

# %%
# sort the DataFrame first by 'star_rating', then by 'duration'
movies.sort_values(['star_rating', 'duration']).head()
# Out:
#      star_rating                title content_rating      genre  duration  \
# 938  7.4          Alice in Wonderland  G              Animation  75
# 948  7.4          Frances Ha           R              Comedy     86
# 966  7.4          The Simpsons Movie   PG-13          Animation  87
# 947  7.4          Eraserhead           UNRATED        Drama      89
# 971  7.4          Death at a Funeral   R              Comedy     90
#
#                                                      actors_list
# 938  [u'Kathryn Beaumont', u'Ed Wynn', u'Richard Haydn']
# 948  [u'Greta Gerwig', u'Mickey Sumner', u'Adam Driver']
# 966  [u'Dan Castellaneta', u'Julie Kavner', u'Nancy Cartwright']
# 947  [u'Jack Nance', u'Charlotte Stewart', u'Allen Joseph']
# 971  [u'Matthew Macfadyen', u'Peter Dinklage', u'Ewen Bremner']

# %% [markdown]
# ### Filter rows in a dataframe by column value

# %%
# read a dataset of top-rated IMDb movies into a DataFrame
movies = pd.read_csv('imdb_1000.csv')
movies.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0  9.3          The Shawshank Redemption  R              Crime   142
# 1  9.2          The Godfather             R              Crime   175
# 2  9.1          The Godfather: Part II    R              Crime   200
# 3  9.0          The Dark Knight           PG-13          Action  152
# 4  8.9          Pulp Fiction              R              Crime   154
#
#                                                 actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunton']
# 1  [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duvall']
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron Eckhart']
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L. Jackson']

# %%
# examine the number of rows and columns
movies.shape
# Out:
# (979, 6)

# %% [markdown]
# #### **Goal:** Filter the rows to only show movies with a 'duration' of at least 200 minutes.

# %%
# create a list in which each element refers to a DataFrame row: True if the row satisfies the condition, False otherwise
booleans = []
for length in movies.duration:
    if length >= 200:
        booleans.append(True)
    else:
        booleans.append(False)

# %%
# confirm that the list has the same length as the DataFrame
len(booleans)
# Out:
# 979

# %%
# examine the first five list elements
booleans[0:5]
# Out:
# [False, False, True, False, False]

# %%
# convert the list to a Series
is_long = pd.Series(booleans)
is_long.head()
# Out:
# 0    False
# 1    False
# 2    True
# 3    False
# 4    False
# dtype: bool

# %%
# use bracket notation with the boolean Series to tell the DataFrame which rows to display
movies[is_long]
# Out:
#      star_rating                                          title  \
# 2    9.1          The Godfather: Part II
# 7    8.9          The Lord of the Rings: The Return of the King
# 17   8.7          Seven Samurai
# 78   8.4          Once Upon a Time in America
# 85   8.4          Lawrence of Arabia
# 142  8.3          Lagaan: Once Upon a Time in India
# 157  8.2          Gone with the Wind
# 204  8.1          Ben-Hur
# 445  7.9          The Ten Commandments
# 476  7.8          Hamlet
# 630  7.7          Malcolm X
# 767  7.6          It's a Mad, Mad, Mad, Mad World
#
#     content_rating      genre  duration  \
# 2    R              Crime      200
# 7    PG-13          Adventure  201
# 17   UNRATED        Drama      207
# 78   R              Crime      229
# 85   PG             Adventure  216
# 142  PG             Adventure  224
# 157  G              Drama      238
# 204  G              Adventure  212
# 445  APPROVED       Adventure  220
# 476  PG-13          Drama      242
# ...

# %% [markdown]
# #### Let's simplify the steps above: there is no need to write a for loop to create the series 'is_long'

# %%
# simplify the steps above: no need to write a for loop to create 'is_long' series
is_long = movies.duration >= 200       # here is_long is a Pandas series
movies[is_long]

# or equivalently, write it in one line (no need to create the 'is_long' series)
movies[movies.duration >= 200]
# Out:
#      star_rating                                          title  \
# 2    9.1          The Godfather: Part II
# 7    8.9          The Lord of the Rings: The Return of the King
# 17   8.7          Seven Samurai
# 78   8.4          Once Upon a Time in America
# 85   8.4          Lawrence of Arabia
# 142  8.3          Lagaan: Once Upon a Time in India
# 157  8.2          Gone with the Wind
# 204  8.1          Ben-Hur
# 445  7.9          The Ten Commandments
# 476  7.8          Hamlet
# 630  7.7          Malcolm X
# 767  7.6          It's a Mad, Mad, Mad, Mad World
#
#     content_rating      genre  duration  \
# 2    R              Crime      200
# 7    PG-13          Adventure  201
# 17   UNRATED        Drama      207
# 78   R              Crime      229
# 85   PG             Adventure  216
# 142  PG             Adventure  224
# 157  G              Drama      238
# 204  G              Adventure  212
# 445  APPROVED       Adventure  220
# 476  PG-13          Drama      242
# ...

# %%
# select the 'genre' Series from the filtered DataFrame
movies[movies.duration >= 200].genre
# Out:
# 2      Crime
# 7      Adventure
# 17     Drama
# 78     Crime
# 85     Adventure
# 142    Adventure
# 157    Drama
# 204    Adventure
# 445    Adventure
# 476    Drama
# 630    Biography
# 767    Action
# Name: genre, dtype: object

# %% [markdown]
# ### Apply multiple filter criteria to a pandas DataFrame

# %%
# read a dataset of top-rated IMDb movies into a DataFrame
movies = pd.read_csv('imdb_1000.csv')

# %% [markdown]
# #### Goal: Filter the long movies (duration >= 200) with a 'genre' of 'Drama'

# %%
# CORRECT: use the '&' operator to specify that both conditions are required
movies[(movies.duration >=200) & (movies.genre == 'Drama')]
# Out:
#      star_rating               title content_rating  genre  duration  \
# 17   8.7          Seven Samurai       UNRATED        Drama  207
# 157  8.2          Gone with the Wind  G              Drama  238
# 476  7.8          Hamlet              PG-13          Drama  242
#
#                                                        actors_list
# 17   [u'Toshir\xf4 Mifune', u'Takashi Shimura', u'Keiko Tsushima']
# 157  [u'Clark Gable', u'Vivien Leigh', u'Thomas Mitchell']
# 476  [u'Kenneth Branagh', u'Julie Christie', u'Derek Jacobi']

# %% [markdown]
# #### Goal: Filter the movies with a 'genre' of 'Crime' or 'Drama' or 'Action'

# %%
# use the '|' operator to specify that a row can match any of the three criteria
movies[(movies.genre == 'Crime') | (movies.genre == 'Drama') | (movies.genre == 'Action')].head(10)
# Out:
#     star_rating                                           title  \
# 0   9.3          The Shawshank Redemption
# 1   9.2          The Godfather
# 2   9.1          The Godfather: Part II
# 3   9.0          The Dark Knight
# 4   8.9          Pulp Fiction
# 5   8.9          12 Angry Men
# 9   8.9          Fight Club
# 11  8.8          Inception
# 12  8.8          Star Wars: Episode V - The Empire Strikes Back
# 13  8.8          Forrest Gump
#
#    content_rating   genre  duration  \
# 0   R              Crime   142
# 1   R              Crime   175
# 2   R              Crime   200
# 3   PG-13          Action  152
# 4   R              Crime   154
# 5   NOT RATED      Drama   96
# 9   R              Drama   139
# 11  PG-13          Action  148
# 12  PG             Action  124
# 13  PG-13          Drama   142
#
#                                                        actors_list
# 0   [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunton']
# 1   [u'Marlon Brando', u'Al Pacino', u'James Caan']
# ...

# %% [markdown]
# ### Iterate over a Series or a DataFrame

# %%
# read a dataset of UFO reports into a DataFrame
ufo = pd.read_csv('ufo.csv')

# %%
# Series are directly iterable (like a list)
for c in ufo.City:
    print(c)
# Out:
# Streaming output truncated to the last 5000 lines.
# Wheeling
# Follansbee
# Marstons Mills
# Kent
# Enola
# Harvey's Lake
# Henderson
# Jenkins
# La Verne
# Pacific Grove
# Norfolk
# Pomona
# Atlanta
# Pittsburgh
# Pittsburgh
# Southington
# Covington
# Carson
# Compton
# Montoursville
# Post
# Issaquah
# Seattle
# Encinitas: along I-5, from encinitas to oceanside over ocean
# Fenton
# Orlando
# Warrensburg
# San Diego
# New York City
# Tijeras
# Natchez
# St. Louis Park
# Coral Gables
# Thornton
# Converse
# Bainbridge Island
# Liberty
# La Mirada
# Fort Worth
# Pullman
# Huntsville
# Mineola
# Baltimore
# Valhermoso Springs
# Lettsworth
# Liberty
# Austin
# Fayetteville
# Lakewood
# Columbia Falls
# Las Cruces
# Kamuela
# Waikoloa
# Fargo
# E. Falmouth
# Cardiff-by-the-Sea
# Glendale
# Ridgecrest
# Manhasset
# Granite City
# Murfeesboro
# Edmond
# Marmora
# VLA Radio Telescope
# Charlotte
# Grand Rapids
# Pleasantville
# Saratoga Lake
# Burke
# Huntington Beach
# Grove City
# ...

# %%
# various methods are available to iterate through a DataFrame, e.g.,
for index, row in ufo.iterrows():
    print(index, row.City, row.State)
# Out:
# Streaming output truncated to the last 5000 lines.
# 13241 Wheeling WV
# 13242 Follansbee WV
# 13243 Marstons Mills MA
# 13244 Kent WA
# 13245 Enola PA
# 13246 Harvey's Lake PA
# 13247 Henderson CO
# 13248 Jenkins KY
# 13249 La Verne CA
# 13250 Pacific Grove CA
# 13251 Norfolk VA
# 13252 Pomona CA
# 13253 Atlanta GA
# 13254 Pittsburgh PA
# 13255 Pittsburgh PA
# 13256 Southington CT
# 13257 Covington WA
# 13258 Carson CA
# 13259 Compton CA
# 13260 Montoursville PA
# 13261 Post TX
# 13262 Issaquah WA
# 13263 Seattle WA
# 13264 Encinitas: along I-5, from encinitas to oceanside over ocean CA
# 13265 Fenton MO
# 13266 Orlando FL
# 13267 Warrensburg NY
# 13268 San Diego CA
# 13269 New York City NY
# 13270 Tijeras NM
# 13271 Natchez MS
# 13272 St. Louis Park MN
# 13273 Coral Gables FL
# 13274 Thornton CO
# 13275 Converse TX
# 13276 Bainbridge Island WA
# 13277 Liberty MO
# 13278 La Mirada CA
# 13279 Fort Worth TX
# 13280 Pullman WA
# 13281 Huntsville AL
# 13282 Mineola TX
# ...

# %% [markdown]
# ### Use a "groupby"

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-31f39c7a-4c01-4024-a20d-2bffb3df1a00" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-31f39c7a-4c01-4024-a20d-2bffb3df1a00">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# read a dataset of alcohol consumption into a DataFrame
drinks = pd.read_csv('drinks.csv')
drinks.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan  0              0                0
# 1  Albania      89             132              54
# 2  Algeria      25             0                14
# 3  Andorra      245            138              312
# 4  Angola       217            57               45
#
#    total_litres_of_pure_alcohol continent
# 0  0.0                           Asia
# 1  4.9                           Europe
# 2  0.7                           Africa
# 3  12.4                          Europe
# 4  5.9                           Africa

# %%
# calculate the mean beer servings across the entire dataset
drinks.beer_servings.mean()
# Out:
# 106.16062176165804

# %%
# calculate the mean beer servings just for countries in Africa
drinks[drinks.continent=='Africa'].beer_servings.mean()
# Out:
# 61.471698113207545

# %%
# calculate the mean beer servings for each continent
drinks.groupby('continent').beer_servings.mean()
# Out:
# continent
# Africa           61.471698
# Asia             37.045455
# Europe           193.777778
# North America    145.434783
# Oceania          89.687500
# South America    175.083333
# Name: beer_servings, dtype: float64

# %% [markdown]
# #### Multiple aggregate functions can be applied simultaneously

# %%
# multiple aggregation functions can be applied simultaneously
drinks.groupby('continent').beer_servings.agg(['count', 'mean', 'min', 'max'])
# Out:
#                count        mean  min  max
# continent
# Africa         53     61.471698   0    376
# Asia           44     37.045455   0    247
# Europe         45     193.777778  0    361
# North America  23     145.434783  1    285
# Oceania        16     89.687500   0    306
# South America  12     175.083333  93   333

# %% [markdown]
# #### Apply an aggregate funtion to every columns

# %%
# specifying a column to which the aggregation function should be applied is not required
drinks.groupby('continent').mean()
# Out:
# <ipython-input-83-5946c12b6d6b>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   drinks.groupby('continent').mean()
#                beer_servings  spirit_servings  wine_servings  \
# continent
# Africa         61.471698      16.339623        16.264151
# Asia           37.045455      60.840909        9.068182
# Europe         193.777778     132.555556       142.222222
# North America  145.434783     165.739130       24.521739
# Oceania        89.687500      58.437500        35.625000
# South America  175.083333     114.750000       62.416667
#
#                total_litres_of_pure_alcohol
# continent
# Africa         3.007547
# Asia           2.170455
# Europe         8.617778
# North America  5.995652
# Oceania        3.381250
# South America  6.308333

# %% [markdown]
# ### Let's plot the data!

# %%
# allow plots to appear in the notebook
# %matplotlib inline

# %%
# side-by-side bar plot of the DataFrame directly above
drinks.groupby('continent').mean().plot(kind='bar')
# Out:
# <ipython-input-85-a7b16681f1b5>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   drinks.groupby('continent').mean().plot(kind='bar')
# <Axes: xlabel='continent'>

# %% [markdown]
# Documentation for [**`plot`**](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.plot.html)

# %% [markdown]
# ### Explore a pandas Series

# %%
# read a dataset of top-rated IMDb movies into a DataFrame
movies = pd.read_csv('imdb_1000.csv')

# %%
# examine the data type of each Series
movies.dtypes
# Out:
# star_rating       float64
# title             object
# content_rating    object
# genre             object
# duration          int64
# actors_list       object
# dtype: object

# %% [markdown]
# **Exploring a non-numeric Series:**

# %%
# count the non-null values, unique values, and frequency of the most common value
movies.genre.describe()
# Out:
# count     979
# unique    16
# top       Drama
# freq      278
# Name: genre, dtype: object

# %% [markdown]
# Documentation for [**`describe`**](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.Series.describe.html)

# %%
# count how many times each value in the Series occurs
movies.genre.value_counts()
# Out:
# Drama        278
# Comedy       156
# Action       136
# Crime        124
# Biography    77
# Adventure    75
# Animation    62
# Horror       29
# Mystery      16
# Western      9
# Sci-Fi       5
# Thriller     5
# Film-Noir    3
# Family       2
# History      1
# Fantasy      1
# Name: genre, dtype: int64

# %% [markdown]
# Documentation for [**`value_counts`**](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.Series.value_counts.html)

# %%
# display percentages instead of raw counts
movies.genre.value_counts(normalize=True)
# Out:
# Drama        0.283963
# Comedy       0.159346
# Action       0.138917
# Crime        0.126660
# Biography    0.078652
# Adventure    0.076609
# Animation    0.063330
# Horror       0.029622
# Mystery      0.016343
# Western      0.009193
# Sci-Fi       0.005107
# Thriller     0.005107
# Film-Noir    0.003064
# Family       0.002043
# History      0.001021
# Fantasy      0.001021
# Name: genre, dtype: float64

# %%
# 'value_counts' (like many pandas methods) outputs a Series
type(movies.genre.value_counts())
# Out:
# pandas.core.series.Series

# %%
# thus, you can add another Series method on the end
movies.genre.value_counts().head()
# Out:
# Drama        278
# Comedy       156
# Action       136
# Crime        124
# Biography    77
# Name: genre, dtype: int64

# %%
# display the unique values in the Series
movies.genre.unique()
# Out:
# array(['Crime', 'Action', 'Drama', 'Western', 'Adventure', 'Biography',
#        'Comedy', 'Animation', 'Mystery', 'Horror', 'Film-Noir', 'Sci-Fi',
#        'History', 'Thriller', 'Family', 'Fantasy'], dtype=object)

# %% [markdown]
# **Exploring a numeric Series:**

# %%
# calculate various summary statistics
movies.duration.describe()
# Out:
# count    979.000000
# mean     120.979571
# std      26.218010
# min      64.000000
# 25%      102.000000
# 50%      117.000000
# 75%      134.000000
# max      242.000000
# Name: duration, dtype: float64

# %%
# many statistics are implemented as Series methods
movies.duration.mean()
# Out:
# 120.97957099080695

# %% [markdown]
# Documentation for [**`mean`**](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.Series.mean.html)

# %%
# allow plots to appear in the notebook
# %matplotlib inline

# %%
# histogram of the 'duration' Series (shows the distribution of a numerical variable)
movies.duration.plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
# bar plot of the 'value_counts' for the 'genre' Series
movies.genre.value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %% [markdown]
# Documentation for [**`plot`**](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.Series.plot.html)

# %% [markdown]
# ### Handling missing values in pandas

# %%
# read a dataset of UFO reports into a DataFrame
ufo = pd.read_csv('ufo.csv')
ufo.tail()
# Out:
#               City Colors Reported Shape Reported State              Time
# 18236  Grant Park   NaN             TRIANGLE       IL    12/31/2000 23:00
# 18237  Spirit Lake  NaN             DISK           IA    12/31/2000 23:00
# 18238  Eagle River  NaN             NaN            WI    12/31/2000 23:45
# 18239  Eagle River  RED             LIGHT          WI    12/31/2000 23:45
# 18240  Ybor         NaN             OVAL           FL    12/31/2000 23:59

# %% [markdown]
# **What does "NaN" mean?**
#
# - "NaN" is not a string, rather it's a special value: **`numpy.nan`**.
# - It stands for "Not a Number" and indicates a **missing value**.
# - **`read_csv`** detects missing values (by default) when reading the file, and replaces them with this special value.
#
# Documentation for [**`read_csv`**](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.read_csv.html)

# %% [markdown]
# #### Function 'isnull' returns a DataFrame of booleans (True if missing, False if not missing)

# %%
# 'isnull' returns a DataFrame of booleans (True if missing, False if not missing)
ufo.isnull().tail()
# Out:
#         City  Colors Reported  Shape Reported  State   Time
# 18236  False  True             False           False  False
# 18237  False  True             False           False  False
# 18238  False  True             True            False  False
# 18239  False  False            False           False  False
# 18240  False  True             False           False  False

# %%
# 'nonnull' returns the opposite of 'isnull' (True if not missing, False if missing)
ufo.notnull().tail()
# Out:
#        City  Colors Reported  Shape Reported  State  Time
# 18236  True  False            True            True   True
# 18237  True  False            True            True   True
# 18238  True  False            False           True   True
# 18239  True  True             True            True   True
# 18240  True  False            True            True   True

# %% [markdown]
# #### Both isnull() and notnull() also apply to a series

# %%
# use the 'notnull' Series method to filter the DataFrame rows
ufo[ufo.City.notnull()].head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0  Ithaca                NaN             TRIANGLE       NY    6/1/1930 22:00
# 1  Willingboro           NaN             OTHER          NJ    6/30/1930 20:00
# 2  Holyoke               NaN             OVAL           CO    2/15/1931 14:00
# 3  Abilene               NaN             DISK           KS    6/1/1931 13:00
# 4  New York Worlds Fair  NaN             LIGHT          NY    4/18/1933 19:00

# %% [markdown]
# *** Alternatively,  use the dataframe function dropna()  ***

# %%
# examine the number of rows and columns
ufo.shape
# Out:
# (18241, 5)

# %%
# if 'any' values are missing in a row, then drop that row. If inplace=True, do operation inplace and return None.
ufo.dropna(how='any', inplace= True)

# %%
ufo.shape
# Out:
# (2486, 5)

# %% [markdown]
# ### Select multiple rows and columns from a DataFrame

# %%
# read a dataset of UFO reports into a DataFrame
ufo = pd.read_csv('ufo.csv')
ufo.head(5)
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0  Ithaca                NaN             TRIANGLE       NY    6/1/1930 22:00
# 1  Willingboro           NaN             OTHER          NJ    6/30/1930 20:00
# 2  Holyoke               NaN             OVAL           CO    2/15/1931 14:00
# 3  Abilene               NaN             DISK           KS    6/1/1931 13:00
# 4  New York Worlds Fair  NaN             LIGHT          NY    4/18/1933 19:00

# %% [markdown]
# The [**`loc`**](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.loc.html) method is used to select rows and columns by ***label***.

# %%
# row 0, all columns
ufo.loc[0, :]
# Out:
# City               Ithaca
# Colors Reported    NaN
# Shape Reported     TRIANGLE
# State              NY
# Time               6/1/1930 22:00
# Name: 0, dtype: object

# %%
# rows 0 and 1 and 2, all columns
ufo.loc[[0, 1, 2], :]
# Out:
#           City Colors Reported Shape Reported State             Time
# 0  Ithaca       NaN             TRIANGLE       NY    6/1/1930 22:00
# 1  Willingboro  NaN             OTHER          NJ    6/30/1930 20:00
# 2  Holyoke      NaN             OVAL           CO    2/15/1931 14:00

# %%
# rows 0 through 2 (inclusive), all columns
ufo.loc[0:2, :]
# Out:
#           City Colors Reported Shape Reported State             Time
# 0  Ithaca       NaN             TRIANGLE       NY    6/1/1930 22:00
# 1  Willingboro  NaN             OTHER          NJ    6/30/1930 20:00
# 2  Holyoke      NaN             OVAL           CO    2/15/1931 14:00

# %%
# rows 0 through 2 (inclusive), columns 'City' and 'State'
ufo.loc[0:2, ['City', 'State']]
# Out:
#           City State
# 0  Ithaca       NY
# 1  Willingboro  NJ
# 2  Holyoke      CO

# %%
# rows in which the 'City' is 'Oakland', column 'State'
ufo.loc[ufo.City=='Oakland', 'State']
# Out:
# 1694     CA
# 2144     CA
# 4686     MD
# 7293     CA
# 8488     CA
# 8768     CA
# 10816    OR
# 10948    CA
# 11045    CA
# 12322    CA
# 12941    CA
# 16803    MD
# 17322    CA
# Name: State, dtype: object

# %% [markdown]
# The [**`iloc`**](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.iloc.html) method is used to select rows and columns by ** integer position**.

# %%
ufo.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0  Ithaca                NaN             TRIANGLE       NY    6/1/1930 22:00
# 1  Willingboro           NaN             OTHER          NJ    6/30/1930 20:00
# 2  Holyoke               NaN             OVAL           CO    2/15/1931 14:00
# 3  Abilene               NaN             DISK           KS    6/1/1931 13:00
# 4  New York Worlds Fair  NaN             LIGHT          NY    4/18/1933 19:00

# %%
# rows in positions 0 and 1, columns in positions 0 and 3
ufo.iloc[[0, 1], [0, 3]]
# Out:
#           City State
# 0  Ithaca       NY
# 1  Willingboro  NJ

# %%
# rows in positions 0 through 2 (exclusive), columns in positions 0 through 4 (exclusive)
ufo.iloc[0:2, 0:4]
# Out:
#           City Colors Reported Shape Reported State
# 0  Ithaca       NaN             TRIANGLE       NY
# 1  Willingboro  NaN             OTHER          NJ

# %%
# rows in positions 0 through 2 (exclusive), all columns
ufo.iloc[0:2, :]
# Out:
#           City Colors Reported Shape Reported State             Time
# 0  Ithaca       NaN             TRIANGLE       NY    6/1/1930 22:00
# 1  Willingboro  NaN             OTHER          NJ    6/30/1930 20:00

# %% [markdown]
# ## Arithmetic Operations

# %%
print(data)

print('Data transpose operation:')
print(data.T)    # transpose operation

print('Addition:')
print(data + 4)    # addition operation

print('Multiplication:')
print(data * 10)   # multiplication operation
# Out:
#          x1        x2        x3
# 0  0.850415 -0.737636 -1.537933
# 1 -0.208407  0.271587 -0.996442
# 2  1.097428  0.962038 -0.516951
# 3 -0.829365 -1.018118 -0.705371
# 4 -2.045070 -0.155677  1.350454
# Data transpose operation:
#            0         1         2         3         4
# x1  0.850415 -0.208407  1.097428 -0.829365 -2.045070
# x2 -0.737636  0.271587  0.962038 -1.018118 -0.155677
# x3 -1.537933 -0.996442 -0.516951 -0.705371  1.350454
# Addition:
#          x1        x2        x3
# 0  4.850415  3.262364  2.462067
# 1  3.791593  4.271587  3.003558
# 2  5.097428  4.962038  3.483049
# 3  3.170635  2.981882  3.294629
# 4  1.954930  3.844323  5.350454
# Multiplication:
#           x1         x2         x3
# 0  8.504153  -7.376358  -15.379326
# 1 -2.084065   2.715867  -9.964422
# 2  10.974282  9.620382  -5.169514
# 3 -8.293650  -10.181180 -7.053711
# 4 -20.450698 -1.556774   13.504542

# %%
print('data =')
print(data)

columnNames = ['x1','x2','x3']
data2 = DataFrame(np.random.randn(5,3), columns=columnNames)
print('\ndata2 =')
print(data2)

print('\ndata + data2 = ')
print(data.add(data2))

print('\ndata * data2 = ')
print(data.mul(data2))
# Out:
# data =
#          x1        x2        x3
# 0  0.850415 -0.737636 -1.537933
# 1 -0.208407  0.271587 -0.996442
# 2  1.097428  0.962038 -0.516951
# 3 -0.829365 -1.018118 -0.705371
# 4 -2.045070 -0.155677  1.350454
#
# data2 =
#          x1        x2        x3
# 0 -1.041921 -0.215085  0.043231
# 1  0.150302 -1.889297 -0.414274
# 2  1.141487 -1.837046  0.457943
# 3 -1.162698 -0.400946  1.409434
# 4 -1.571687 -0.930986 -1.922759
#
# data + data2 =
#          x1        x2        x3
# 0 -0.191506 -0.952720 -1.494702
# 1 -0.058104 -1.617710 -1.410716
# 2  2.238916 -0.875008 -0.059008
# 3 -1.992063 -1.419064  0.704063
# 4 -3.616757 -1.086663 -0.572305
#
# data * data2 =
#          x1        x2        x3
# 0 -0.886066  0.158654 -0.066486
# 1 -0.031324 -0.513108  0.412800
# 2  1.252700 -1.767309 -0.236734
# 3  0.964301  0.408210 -0.994174
# 4  3.214210  0.144933 -2.596598

# %%
print(data.abs())    # get the absolute value for each element

print('\nMaximum value per column:')
print(data.max())    # get maximum value for each column

print('\nMinimum value per row:')
print(data.min(axis=1))    # get minimum value for each row

print('\nSum of values per column:')
print(data.sum())    # get sum of values for each column

print('\nAverage value per row:')
print(data.mean(axis=1))    # get average value for each row

print('\nCalculate max - min per column')
f = lambda x: x.max() - x.min()
print(data.apply(f))

print('\nCalculate max - min per row')
f = lambda x: x.max() - x.min()
print(data.apply(f, axis=1))
# Out:
#          x1        x2        x3
# 0  0.850415  0.737636  1.537933
# 1  0.208407  0.271587  0.996442
# 2  1.097428  0.962038  0.516951
# 3  0.829365  1.018118  0.705371
# 4  2.045070  0.155677  1.350454
#
# Maximum value per column:
# x1    1.097428
# x2    0.962038
# x3    1.350454
# dtype: float64
#
# Minimum value per row:
# 0   -1.537933
# 1   -0.996442
# 2   -0.516951
# 3   -1.018118
# 4   -2.045070
# dtype: float64
#
# Sum of values per column:
# x1   -1.134998
# x2   -0.677806
# x3   -2.406243
# dtype: float64
#
# Average value per row:
# 0   -0.475051
# 1   -0.311087
# 2    0.514172
# 3   -0.850951
# 4   -0.283431
# dtype: float64
#
# Calculate max - min per column
# x1    3.142498
# x2    1.980156
# x3    2.888387
# dtype: float64
#
# Calculate max - min per row
# 0    2.388348
# 1    1.268029
# 2    1.614380
# 3    0.312747
# 4    3.395524
# dtype: float64

# %% [markdown]
# ## Plotting Series and DataFrame
#
# There are built-in functions you can use to plot the data stored in a Series or a DataFrame.

# %%
# %matplotlib inline

s3 = Series([1.2,2.5,-2.2,3.1,-0.8,-3.2,1.4],
            index = ['Jan 1','Jan 2','Jan 3','Jan 4','Jan 5','Jan 6','Jan 7'])
s3.plot(kind='line', title='Line plot')
# Out:
# <Axes: title={'center': 'Line plot'}>

# %%
s3.plot(kind='bar', title='Bar plot')
# Out:
# <Axes: title={'center': 'Bar plot'}>

# %%
s3.plot(kind='hist', title = 'Histogram')
# Out:
# <Axes: title={'center': 'Histogram'}, ylabel='Frequency'>

# %%
tuplelist = [(2011,45.1,32.4),(2012,42.4,34.5),(2013,47.2,39.2),
              (2014,44.2,31.4),(2015,39.9,29.8),(2016,41.5,36.7)]
columnNames = ['year','temp','precip']
weatherData = DataFrame(tuplelist, columns=columnNames)
weatherData[['temp','precip']].plot(kind='box', title='Box plot')
# Out:
# <Axes: title={'center': 'Box plot'}>
